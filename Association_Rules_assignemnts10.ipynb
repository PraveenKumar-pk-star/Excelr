# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenKumar-pk-star/Excelr/blob/main/Association_Rules_assignemnts10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Load the data
data = pd.read_excel('/content/Online retail.xlsx', header=None)
data.head()
# Out:
#                                                    0
# 0  shrimp,almonds,avocado,vegetables mix,green gr...
# 1                             burgers,meatballs,eggs
# 2                                            chutney
# 3                                     turkey,avocado
# 4  mineral water,milk,energy bar,whole wheat rice...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7501 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB

# %%
data.isnull().sum()
# Out:
# 0    0
# dtype: int64

# %%
data.describe()
# Out:
#               0
# count      7501
# unique     5176
# top     cookies
# freq        223

# %%
data.columns = ['Transactions']

# %%
# Split the transactions into a list of items
data['Transactions'] = data['Transactions'].apply(lambda x: x.split(','))

# %%
# Convert transactions into the required format
te = TransactionEncoder()
te_ary = te.fit(data['Transactions']).transform(data['Transactions'])
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
#       bacon  barbecue sauce  black tea  blueberries  ...  turkey  \
# 0     False           False      False        False  ...   False
# 1     False           False      False        False  ...   False
# 2     False           False      False        False  ...   False
# 3     False           False      False        False  ...    True
# 4     False           False      False        False  ...   False
# ...     ...             ...        ...          ...  ...     ...
# 7496  False           False      False        False  ...   False
# 7497  False           False      False        False  ...   False
# 7498  False           False      False        False  ...   False
# 7499  False           False      False        False  ...   False
# 7500  False           False      False        False  ...   False
#
#       vegetables mix  water spray  white wine  whole weat flour  \
# 0               True        False       False              True
# 1              False        False       False             False
# 2              False        False       False             False
# 3              False        False       False             False
# 4              False        False       False             False
# ...              ...          ...         ...               ...
# 7496           False        False       False             False
# 7497           False        False       False             False
# 7498           False        False       False             False
# 7499           False        False       False             False
# 7500           False        False       False             False
#
#       whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0                 False             False   True        False     False
# 1                 False             False  False        False     False
# 2                 False             False  False        False     False
# 3                 False             False  False        False     False
# 4                 False              True  False        False     False
# ...                 ...               ...    ...          ...       ...
# 7496              False             False  False        False     False
# 7497              False             False  False        False     False
# 7498              False             False  False        False     False
# 7499              False             False  False        False     False
# 7500              False             False  False         True     False
#
# [7501 rows x 120 columns]

# %%
# Apply the Apriori algorithm
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (ground beef, mineral water, milk)
# 253  0.017064  (ground beef, mineral water, spaghetti)
# 254  0.015731         (mineral water, milk, spaghetti)
# 255  0.010265    (olive oil, mineral water, spaghetti)
# 256  0.011465     (spaghetti, mineral water, pancakes)
#
# [257 rows x 2 columns]

# %%
# Generate the association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Display the rules
print(rules.head())
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0  (mineral water)        (avocado)            0.238368            0.033329
# 1        (avocado)  (mineral water)            0.033329            0.238368
# 2        (burgers)           (cake)            0.087188            0.081056
# 3           (cake)        (burgers)            0.081056            0.087188
# 4        (burgers)      (chocolate)            0.087188            0.163845
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0  0.011598    0.048658  1.459926               1.0  0.003654    1.016113
# 1  0.011598    0.348000  1.459926               1.0  0.003654    1.168147
# 2  0.011465    0.131498  1.622319               1.0  0.004398    1.058080
# 3  0.011465    0.141447  1.622319               1.0  0.004398    1.063198
# 4  0.017064    0.195719  1.194537               1.0  0.002779    1.039630
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.413630  0.044593   0.015857    0.198329
# 1       0.325896  0.044593   0.143943    0.198329
# 2       0.420238  0.073129   0.054892    0.136473
# 3       0.417434  0.073129   0.059442    0.136473
# 4       0.178411  0.072934   0.038120    0.149934

# %%
# Display the rules
print("Top 5 rules based on lift:")
print(rules.nlargest(5, 'lift'))

# Sort the rules by confidence and display the top 5
print("\nTop 5 rules based on confidence:")
print(rules.nlargest(5, 'confidence'))

# Sort the rules by support and display the top 5
print("\nTop 5 rules based on support:")
print(rules.nlargest(5, 'support'))

# Further analysis to interpret the results
# Identify frequent antecedents and consequents
frequent_antecedents = rules['antecedents'].value_counts().head()
frequent_consequents = rules['consequents'].value_counts().head()

print("\nMost frequent antecedents:")
print(frequent_antecedents)

print("\nMost frequent consequents:")
print(frequent_consequents)

# Example of interpreting a rule
example_rule = rules.iloc[0]
antecedents = list(example_rule['antecedents'])
consequents = list(example_rule['consequents'])
confidence = example_rule['confidence']
lift = example_rule['lift']

print(f"\nExample Rule Interpretation:\nIf a customer buys {antecedents}, they are likely to buy {consequents} as well.")
print(f"Confidence: {confidence}, Lift: {lift}")
# Out:
# Top 5 rules based on lift:
#                     antecedents                 consequents  \
# 214             (herb & pepper)               (ground beef)
# 215               (ground beef)             (herb & pepper)
# 384  (mineral water, spaghetti)               (ground beef)
# 385               (ground beef)  (mineral water, spaghetti)
# 396  (mineral water, spaghetti)                 (olive oil)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 214            0.049460            0.098254  0.015998    0.323450  3.291994
# 215            0.098254            0.049460  0.015998    0.162822  3.291994
# 384            0.059725            0.098254  0.017064    0.285714  2.907928
# 385            0.098254            0.059725  0.017064    0.173677  2.907928
# 396            0.059725            0.065858  0.010265    0.171875  2.609786
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 214               1.0  0.011138    1.332860       0.732460  0.121457
# 215               1.0  0.011138    1.135410       0.772094  0.121457
# 384               1.0  0.011196    1.262445       0.697788  0.121097
# 385               1.0  0.011196    1.137902       0.727602  0.121097
# 396               1.0  0.006332    1.128021       0.656007  0.089017
#
#      certainty  kulczynski
# 214   0.249734    0.243136
# 215   0.119261    0.243136
# 384   0.207886    0.229696
# 385   0.121190    0.229696
# 396   0.113491    0.163873
#
# Top 5 rules based on confidence:
#                    antecedents      consequents  antecedent support  \
# 342        (eggs, ground beef)  (mineral water)            0.019997
# 377        (ground beef, milk)  (mineral water)            0.021997
# 319   (ground beef, chocolate)  (mineral water)            0.023064
# 366  (frozen vegetables, milk)  (mineral water)            0.023597
# 273                     (soup)  (mineral water)            0.050527
#
#      consequent support   support  confidence      lift  representativity  \
# 342            0.238368  0.010132    0.506667  2.125563               1.0
# 377            0.238368  0.011065    0.503030  2.110308               1.0
# 319            0.238368  0.010932    0.473988  1.988472               1.0
# 366            0.238368  0.011065    0.468927  1.967236               1.0
# 273            0.238368  0.023064    0.456464  1.914955               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 342  0.005365    1.543848       0.540342  0.040816   0.352268    0.274586
# 377  0.005822    1.532552       0.537969  0.044385   0.347493    0.274725
# 319  0.005434    1.447937       0.508837  0.043640   0.309362    0.259925
# 366  0.005440    1.434136       0.503555  0.044102   0.302716    0.257674
# 273  0.011020    1.401255       0.503221  0.086760   0.286354    0.276610
#
# Top 5 rules based on support:
#          antecedents      consequents  antecedent support  consequent support  \
# 274  (mineral water)      (spaghetti)            0.238368            0.174110
# 275      (spaghetti)  (mineral water)            0.174110            0.238368
# 84   (mineral water)      (chocolate)            0.238368            0.163845
# 85       (chocolate)  (mineral water)            0.163845            0.238368
# 128           (eggs)  (mineral water)            0.179709            0.238368
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 274  0.059725    0.250559  1.439085               1.0  0.018223    1.102008
# 275  0.059725    0.343032  1.439085               1.0  0.018223    1.159314
# 84   0.052660    0.220917  1.348332               1.0  0.013604    1.073256
# 85   0.052660    0.321400  1.348332               1.0  0.013604    1.122357
# 128  0.050927    0.283383  1.188845               1.0  0.008090    1.062815
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 274       0.400606  0.169312   0.092566    0.296796
# 275       0.369437  0.169312   0.137421    0.296796
# 84        0.339197  0.150648   0.068256    0.271158
# 85        0.308965  0.150648   0.109018    0.271158
# 128       0.193648  0.138707   0.059103    0.248515
#
# Most frequent antecedents:
# antecedents
# (mineral water)    42
# (spaghetti)        36
# (chocolate)        31
# (milk)             27
# (eggs)             24
# Name: count, dtype: int64
#
# Most frequent consequents:
# consequents
# (mineral water)    42
# (spaghetti)        36
# (chocolate)        31
# (milk)             27
# (eggs)             24
# Name: count, dtype: int64
#
# Example Rule Interpretation:
# If a customer buys ['mineral water'], they are likely to buy ['avocado'] as well.
# Confidence: 0.04865771812080537, Lift: 1.4599261744966443

# %%
# Display the rules
print("Top 5 rules based on lift:")
print(rules.nlargest(5, 'lift'))

# Sort the rules by confidence and display the top 5
print("\nTop 5 rules based on confidence:")
print(rules.nlargest(5, 'confidence'))

# Sort the rules by support and display the top 5
print("\nTop 5 rules based on support:")
print(rules.nlargest(5, 'support'))

# Further analysis to interpret the results
# Identify frequent antecedents and consequents
frequent_antecedents = rules['antecedents'].value_counts().head()
frequent_consequents = rules['consequents'].value_counts().head()

print("\nMost frequent antecedents:")
print(frequent_antecedents)

print("\nMost frequent consequents:")
print(frequent_consequents)

# Example of interpreting a rule
example_rule = rules.iloc[0]
antecedents = list(example_rule['antecedents'])
consequents = list(example_rule['consequents'])
confidence = example_rule['confidence']
lift = example_rule['lift']

print(f"\nExample Rule Interpretation:\nIf a customer buys {antecedents}, they are likely to buy {consequents} as well.")
print(f"Confidence: {confidence}, Lift: {lift}")
# Out:
# Top 5 rules based on lift:
#                     antecedents                 consequents  \
# 214             (herb & pepper)               (ground beef)
# 215               (ground beef)             (herb & pepper)
# 384  (mineral water, spaghetti)               (ground beef)
# 385               (ground beef)  (mineral water, spaghetti)
# 396  (mineral water, spaghetti)                 (olive oil)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 214            0.049460            0.098254  0.015998    0.323450  3.291994
# 215            0.098254            0.049460  0.015998    0.162822  3.291994
# 384            0.059725            0.098254  0.017064    0.285714  2.907928
# 385            0.098254            0.059725  0.017064    0.173677  2.907928
# 396            0.059725            0.065858  0.010265    0.171875  2.609786
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 214               1.0  0.011138    1.332860       0.732460  0.121457
# 215               1.0  0.011138    1.135410       0.772094  0.121457
# 384               1.0  0.011196    1.262445       0.697788  0.121097
# 385               1.0  0.011196    1.137902       0.727602  0.121097
# 396               1.0  0.006332    1.128021       0.656007  0.089017
#
#      certainty  kulczynski
# 214   0.249734    0.243136
# 215   0.119261    0.243136
# 384   0.207886    0.229696
# 385   0.121190    0.229696
# 396   0.113491    0.163873
#
# Top 5 rules based on confidence:
#                    antecedents      consequents  antecedent support  \
# 342        (eggs, ground beef)  (mineral water)            0.019997
# 377        (ground beef, milk)  (mineral water)            0.021997
# 319   (ground beef, chocolate)  (mineral water)            0.023064
# 366  (frozen vegetables, milk)  (mineral water)            0.023597
# 273                     (soup)  (mineral water)            0.050527
#
#      consequent support   support  confidence      lift  representativity  \
# 342            0.238368  0.010132    0.506667  2.125563               1.0
# 377            0.238368  0.011065    0.503030  2.110308               1.0
# 319            0.238368  0.010932    0.473988  1.988472               1.0
# 366            0.238368  0.011065    0.468927  1.967236               1.0
# 273            0.238368  0.023064    0.456464  1.914955               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 342  0.005365    1.543848       0.540342  0.040816   0.352268    0.274586
# 377  0.005822    1.532552       0.537969  0.044385   0.347493    0.274725
# 319  0.005434    1.447937       0.508837  0.043640   0.309362    0.259925
# 366  0.005440    1.434136       0.503555  0.044102   0.302716    0.257674
# 273  0.011020    1.401255       0.503221  0.086760   0.286354    0.276610
#
# Top 5 rules based on support:
#          antecedents      consequents  antecedent support  consequent support  \
# 274  (mineral water)      (spaghetti)            0.238368            0.174110
# 275      (spaghetti)  (mineral water)            0.174110            0.238368
# 84   (mineral water)      (chocolate)            0.238368            0.163845
# 85       (chocolate)  (mineral water)            0.163845            0.238368
# 128           (eggs)  (mineral water)            0.179709            0.238368
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 274  0.059725    0.250559  1.439085               1.0  0.018223    1.102008
# 275  0.059725    0.343032  1.439085               1.0  0.018223    1.159314
# 84   0.052660    0.220917  1.348332               1.0  0.013604    1.073256
# 85   0.052660    0.321400  1.348332               1.0  0.013604    1.122357
# 128  0.050927    0.283383  1.188845               1.0  0.008090    1.062815
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 274       0.400606  0.169312   0.092566    0.296796
# 275       0.369437  0.169312   0.137421    0.296796
# 84        0.339197  0.150648   0.068256    0.271158
# 85        0.308965  0.150648   0.109018    0.271158
# 128       0.193648  0.138707   0.059103    0.248515
#
# Most frequent antecedents:
# antecedents
# (mineral water)    42
# (spaghetti)        36
# (chocolate)        31
# (milk)             27
# (eggs)             24
# Name: count, dtype: int64
#
# Most frequent consequents:
# consequents
# (mineral water)    42
# (spaghetti)        36
# (chocolate)        31
# (milk)             27
# (eggs)             24
# Name: count, dtype: int64
#
# Example Rule Interpretation:
# If a customer buys ['mineral water'], they are likely to buy ['avocado'] as well.
# Confidence: 0.04865771812080537, Lift: 1.4599261744966443

# %% [markdown]
# interview Questions
#
# 1. What is lift and why is it important in Association rules?
#
#    Lift measures how much more likely two items are to occur together than expected if they were independent; a lift > 1 indicates a positive association.
#
# 2. What is support and Confidence How do you calculate them?
#
#    Support is the proportion of transactions that contain an itemset:
#    Support(A) = (Transactions containing A) / (Total transactions)
#
#    Confidence is the likelihood of item B being bought when item A is bought:
#    Confidence(A → B) = Support(A ∪ B) / Support(A)
#
# 3. What are some limitations or challenges of Association rules mining?
#
#    It can generate too many trivial or irrelevant rules, and it struggles with sparse data and setting appropriate thresholds for support and confidence.
